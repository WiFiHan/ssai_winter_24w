# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 아래 코드 실행 후 반드시 "내 드라이브" 첫 화면에 lec1 폴더가 있는지 확인
# %cd /content/drive/MyDrive
# !git clone --no-checkout --filter=blob:none https://github.com/WiFiHan/ssai_winter_24w.git
# %cd ssai_winter_24w
# !git sparse-checkout init --cone
# !git sparse-checkout set lec1
# !git checkout main
# Out:
# /content/drive/MyDrive
# Cloning into 'ssai_winter_24w'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 104 (delta 34), reused 37 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (104/104), 26.02 KiB | 1.45 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/drive/MyDrive/ssai_winter_24w
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 11.57 KiB | 911.00 KiB/s, done.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
